# %%
import pandas as pd
import sys

# %%
df = pd.read_excel("C:\\Users\\USER\\Downloads\\sagacious telegram task\\BIGC Model (1) (1).xlsx",sheet_name = 'Data extraction',
                  usecols= "B:AC", header=None)
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
author_name, ticker_name = df.loc[2,3], df.loc[1,3]

# %%
category = list(df[1].dropna()[:3])
category_list = [['Revenue','COGS (ex D&A)'], ['Cash & Short-Term Investments'], ['Depreciation & Amortization', 
                    'Change in Net Working Capital']]
categories = {k:v for k,v in zip(category, category_list)}
categories
# Out:
# {'Income Statement Inputs': ['Revenue', 'COGS (ex D&A)'],
#  'Balance Sheet Inputs': ['Cash & Short-Term Investments'],
#  'Cash Flow Statement Inputs': ['Depreciation & Amortization',
#   'Change in Net Working Capital']}

# %%
dff = df.loc[df[2].isin(['Revenue', 'COGS (ex D&A)', 'Line Item', 'Cash & Short-Term Investments', 'Depreciation & Amortization'
                        ,'Change in Net Working Capital'])]
dff
# Out:
#      1                              2    3    4    5    6    7       8   \
# 7   NaN                      Line Item  NaN   Q1   Q2   Q3   Q4      FY
# 9   NaN                        Revenue  NaN  NaN  NaN  NaN  NaN  91.867
# 10  NaN                  COGS (ex D&A)  NaN  NaN  NaN  NaN  NaN  21.937
# 26  NaN  Cash & Short-Term Investments  NaN  NaN  NaN  NaN  NaN   36.16
# 44  NaN    Depreciation & Amortization  NaN  NaN  NaN  NaN  NaN  10.341
# 45  NaN  Change in Net Working Capital  NaN  NaN  NaN  NaN  NaN   4.629
#
#         9       10      11     12       13      14      15       16       17  \
# 7       Q1      Q2      Q3     Q4       FY      Q1      Q2       Q3       Q4
# 9   25.584  27.235  28.264  31.02  112.103  33.174  36.316   39.735   43.143
# 10   5.925   6.227   6.806  8.065   27.023    7.48   7.837    8.593   10.216
# 26     NaN     NaN     NaN  7.795    7.795  33.026   25.39  178.846  219.447
# 44     NaN     NaN     NaN    NaN    2.569     NaN     NaN      NaN      NaN
# 45     NaN     NaN     NaN    NaN   -3.174     NaN     NaN      NaN      NaN
#
#          18       19       20   21   22          23   24   25          26  \
# 7        FY       Q1       Q2   Q3   Q4          FY   Q1   Q2          FY
# 9   152.368    46.66   49.013  NaN  NaN   197.53843  NaN  NaN  254.753589
# 10   34.126     9.25   10.185  NaN  NaN   46.816608  NaN  NaN    58.02013
# 26  219.447  207.952  203.269  NaN  NaN  180.331493  NaN  NaN  148.083685
# 44    3.084      NaN      NaN  NaN  NaN      2.8446  NaN  NaN    2.792403
# 45     1.33      NaN      NaN  NaN  NaN    -1.92519  NaN  NaN   -5.147672
#
#             27          28
# 7           FY          FY
# 9   318.955022  391.767365
# 10   69.691672   81.977321
# 26   133.94675  144.329331
# 44    2.819669    2.910286
# 45   -6.535872   -7.560022

# %%
estimate_or_actual = df.iloc[5, 4:]
e_or_a_table = pd.DataFrame(estimate_or_actual)
e_or_a_table_transpose = e_or_a_table.T

working_table = pd.concat([e_or_a_table_transpose, dff], ignore_index=True)
working_table_clean = working_table.set_index(2).T.dropna()
working_table_final = working_table_clean.rename(columns=str).rename(columns={'nan':'Estimate/Actual'})
working_table_final
# Out:
# 2  Estimate/Actual Line Item     Revenue COGS (ex D&A)  \
# 8           Actual        FY      91.867        21.937
# 13          Actual        FY     112.103        27.023
# 18          Actual        FY     152.368        34.126
# 23        Estimate        FY   197.53843     46.816608
# 26        Estimate        FY  254.753589      58.02013
# 27        Estimate        FY  318.955022     69.691672
# 28        Estimate        FY  391.767365     81.977321
#
# 2  Cash & Short-Term Investments Depreciation & Amortization  \
# 8                          36.16                      10.341
# 13                         7.795                       2.569
# 18                       219.447                       3.084
# 23                    180.331493                      2.8446
# 26                    148.083685                    2.792403
# 27                     133.94675                    2.819669
# 28                    144.329331                    2.910286
#
# 2  Change in Net Working Capital
# 8                          4.629
# 13                        -3.174
# 18                          1.33
# 23                      -1.92519
# 26                     -5.147672
# 27                     -6.535872
# 28                     -7.560022

# %%
final_df = pd.DataFrame()
working_table_final_columns = list(working_table_final.columns)[2:]

year_list = ['2018', '2019', '2020', '2021', '2022', '2023', '2024']

for i in working_table_final_columns:
    final_df = pd.concat([final_df, pd.DataFrame({'Author Name': author_name,
                                                  'Ticker Name': ticker_name,
                                                  'Category': [k for k,v in categories.items() if i in v][0],
                                                  'Line Item': i,
                                                  'Year': year_list,
                                                  'Period': working_table_final['Line Item'],
                                                  'Estimate/Actual': working_table_final['Estimate/Actual'],
                                                  'Value': working_table_final[i]})], 
                                                ignore_index=True)

final_df
# Out:
#           Author Name     Ticker Name                    Category  \
# 0   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 1   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 2   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 3   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 4   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 5   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 6   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 7   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 8   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 9   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 10  sample@sample.com  BIGC US Equity     Income Statement Inputs
# 11  sample@sample.com  BIGC US Equity     Income Statement Inputs
# 12  sample@sample.com  BIGC US Equity     Income Statement Inputs
# 13  sample@sample.com  BIGC US Equity     Income Statement Inputs
# 14  sample@sample.com  BIGC US Equity        Balance Sheet Inputs
# 15  sample@sample.com  BIGC US Equity        Balance Sheet Inputs
# 16  sample@sample.com  BIGC US Equity        Balance Sheet Inputs
# 17  sample@sample.com  BIGC US Equity        Balance Sheet Inputs
# 18  sample@sample.com  BIGC US Equity        Balance Sheet Inputs
# 19  sample@sample.com  BIGC US Equity        Balance Sheet Inputs
# 20  sample@sample.com  BIGC US Equity        Balance Sheet Inputs
# 21  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 22  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 23  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 24  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 25  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 26  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 27  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 28  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 29  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 30  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 31  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 32  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 33  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 34  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
#
#                         Line Item  Year Period Estimate/Actual       Value
# 0                         Revenue  2018     FY          Actual      91.867
# 1                         Revenue  2019     FY          Actual     112.103
# 2                         Revenue  2020     FY          Actual     152.368
# 3                         Revenue  2021     FY        Estimate   197.53843
# 4                         Revenue  2022     FY        Estimate  254.753589
# 5                         Revenue  2023     FY        Estimate  318.955022
# 6                         Revenue  2024     FY        Estimate  391.767365
# 7                   COGS (ex D&A)  2018     FY          Actual      21.937
# 8                   COGS (ex D&A)  2019     FY          Actual      27.023
# 9                   COGS (ex D&A)  2020     FY          Actual      34.126
# 10                  COGS (ex D&A)  2021     FY        Estimate   46.816608
# 11                  COGS (ex D&A)  2022     FY        Estimate    58.02013
# 12                  COGS (ex D&A)  2023     FY        Estimate   69.691672
# 13                  COGS (ex D&A)  2024     FY        Estimate   81.977321
# 14  Cash & Short-Term Investments  2018     FY          Actual       36.16
# 15  Cash & Short-Term Investments  2019     FY          Actual       7.795
# 16  Cash & Short-Term Investments  2020     FY          Actual     219.447
# 17  Cash & Short-Term Investments  2021     FY        Estimate  180.331493
# 18  Cash & Short-Term Investments  2022     FY        Estimate  148.083685
# 19  Cash & Short-Term Investments  2023     FY        Estimate   133.94675
# 20  Cash & Short-Term Investments  2024     FY        Estimate  144.329331
# 21    Depreciation & Amortization  2018     FY          Actual      10.341
# 22    Depreciation & Amortization  2019     FY          Actual       2.569
# 23    Depreciation & Amortization  2020     FY          Actual       3.084
# 24    Depreciation & Amortization  2021     FY        Estimate      2.8446
# 25    Depreciation & Amortization  2022     FY        Estimate    2.792403
# 26    Depreciation & Amortization  2023     FY        Estimate    2.819669
# 27    Depreciation & Amortization  2024     FY        Estimate    2.910286
# 28  Change in Net Working Capital  2018     FY          Actual       4.629
# 29  Change in Net Working Capital  2019     FY          Actual      -3.174
# 30  Change in Net Working Capital  2020     FY          Actual        1.33
# 31  Change in Net Working Capital  2021     FY        Estimate    -1.92519
# 32  Change in Net Working Capital  2022     FY        Estimate   -5.147672
# 33  Change in Net Working Capital  2023     FY        Estimate   -6.535872
# 34  Change in Net Working Capital  2024     FY        Estimate   -7.560022

# %%
rev_yr = final_df[final_df['Line Item'] == 'Revenue']

# %%
r = final_df.loc[(final_df['Year'].isin(['2018','2019', '2020']))]
cash_yr = r[r['Line Item'] == 'Cash & Short-Term Investments']
cogs_yr = r[r['Line Item'] == 'COGS (ex D&A)']

# %%
o = final_df.loc[(final_df['Year'].isin(['2018','2019', '2020', '2021']))]
dep_yr = o[o['Line Item'] == 'Depreciation & Amortization']

# %%
q = final_df.loc[(final_df['Year'].isin(['2021', '2022', '2023']))]
change_yr = q[q['Line Item'] == 'Change in Net Working Capital']

# %%
actual_final_df = pd.concat([rev_yr,cogs_yr,cash_yr,dep_yr,change_yr], ignore_index=True)
actual_final_df
# Out:
#           Author Name     Ticker Name                    Category  \
# 0   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 1   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 2   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 3   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 4   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 5   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 6   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 7   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 8   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 9   sample@sample.com  BIGC US Equity     Income Statement Inputs
# 10  sample@sample.com  BIGC US Equity        Balance Sheet Inputs
# 11  sample@sample.com  BIGC US Equity        Balance Sheet Inputs
# 12  sample@sample.com  BIGC US Equity        Balance Sheet Inputs
# 13  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 14  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 15  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 16  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 17  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 18  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
# 19  sample@sample.com  BIGC US Equity  Cash Flow Statement Inputs
#
#                         Line Item  Year Period Estimate/Actual       Value
# 0                         Revenue  2018     FY          Actual      91.867
# 1                         Revenue  2019     FY          Actual     112.103
# 2                         Revenue  2020     FY          Actual     152.368
# 3                         Revenue  2021     FY        Estimate   197.53843
# 4                         Revenue  2022     FY        Estimate  254.753589
# 5                         Revenue  2023     FY        Estimate  318.955022
# 6                         Revenue  2024     FY        Estimate  391.767365
# 7                   COGS (ex D&A)  2018     FY          Actual      21.937
# 8                   COGS (ex D&A)  2019     FY          Actual      27.023
# 9                   COGS (ex D&A)  2020     FY          Actual      34.126
# 10  Cash & Short-Term Investments  2018     FY          Actual       36.16
# 11  Cash & Short-Term Investments  2019     FY          Actual       7.795
# 12  Cash & Short-Term Investments  2020     FY          Actual     219.447
# 13    Depreciation & Amortization  2018     FY          Actual      10.341
# 14    Depreciation & Amortization  2019     FY          Actual       2.569
# 15    Depreciation & Amortization  2020     FY          Actual       3.084
# 16    Depreciation & Amortization  2021     FY        Estimate      2.8446
# 17  Change in Net Working Capital  2021     FY        Estimate    -1.92519
# 18  Change in Net Working Capital  2022     FY        Estimate   -5.147672
# 19  Change in Net Working Capital  2023     FY        Estimate   -6.535872

# %%
actual_final_df.to_csv('out.csv', index=False)
